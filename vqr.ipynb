# %%
import numpy as np
import scipy as sp
import cvxpy as cp

# %%
# Reload random seed
np.random.seed(2025)
rng = np.random.default_rng()

# Parameters
NUM_DEPARTMENTS = 5
NUM_AUTHORS = 200
NUM_PRODUCTS = 1000

MULTIPLICATIVE_FACTOR = 2.5 ## The corretion term for the total number of paper submitted by each department
MAX_NUM_RP_PER_AUTHOR = 4
MIN_NUM_RP_PER_AUTHOR = 1
MAX_NUM_AUTHORS_RP_SAME_DEPARTMENT = 1
MAX_NUM_DEPARTMENTS_PRESENTING_SAME_RP = 2
MAX_GRADE = 5
MIN_GRADE = 1
AVG_GRADE = np.random.uniform(MIN_GRADE, MAX_GRADE, NUM_PRODUCTS)
VAR_GRADE = np.random.uniform(0, 1.5**2, NUM_PRODUCTS)

AUTHOR_WEIGHT = np.random.randint(1, 3, NUM_AUTHORS)
COVARIANCE_MATRIX = sp.sparse.bsr_array(np.diag(VAR_GRADE)) # sparse

# %%
## Make sure that all papers have (at least) one author and all authors have (at least) one paper
## and try to make it similar to a random assignment
AUTHORSHIP = cp.Variable((NUM_AUTHORS, NUM_PRODUCTS), boolean=True)
cp.Problem(
    cp.Minimize(cp.norm(AUTHORSHIP - np.random.randint(0, 2, (NUM_AUTHORS, NUM_PRODUCTS)), 1)), 
    [cp.sum(AUTHORSHIP, axis=0) >= 1, cp.sum(AUTHORSHIP, axis=1) >= 1]
).solve(verbose=True)

AUTHORSHIP = sp.sparse.bsr_array(AUTHORSHIP.value) # sparse
sp.sparse.save_npz("data/authorship.npz", AUTHORSHIP)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:37:22 PM: Your problem has 200000 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:37:22 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:37:22 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:37:22 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:37:22 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:22 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:37:22 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:37:22 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:37:22 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:37:22 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:37:22 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:37:22 PM: Finished problem compilation (took 8.224e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:22 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:37:23 PM: Problem
# (CVXPY) Mar 25 10:37:23 PM:   Name                   :
# (CVXPY) Mar 25 10:37:23 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:37:23 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:37:23 PM:   Constraints            : 402200
# (CVXPY) Mar 25 10:37:23 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:37:23 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:37:23 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:37:23 PM:   Scalar variables       : 400001
# (CVXPY) Mar 25 10:37:23 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:37:23 PM:   Integer variables      : 200000
# (CVXPY) Mar 25 10:37:23 PM:
# (CVXPY) Mar 25 10:37:23 PM: Optimizer started.
# (CVXPY) Mar 25 10:37:23 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:37:23 PM: Threads used: 4
# (CVXPY) Mar 25 10:37:23 PM: Presolve started.
# (CVXPY) Mar 25 10:37:24 PM: Presolve terminated. Time = 0.97, probing time =  0.00
# (CVXPY) Mar 25 10:37:24 PM: Presolved problem: 0 variables, 0 constraints, 0 non-zeros
# (CVXPY) Mar 25 10:37:24 PM: Presolved problem: 0 general integer, 0 binary, 0 continuous
# (CVXPY) Mar 25 10:37:24 PM: Clique table size: 0
# (CVXPY) Mar 25 10:37:24 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:37:24 PM: 0        0        1        0        0.0000000000e+00     NA                   NA          1.6
# (CVXPY) Mar 25 10:37:24 PM: 0        1        1        0        0.0000000000e+00     0.0000000000e+00     0.00e+00    1.6
# (CVXPY) Mar 25 10:37:24 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 25 10:37:24 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 25 10:37:24 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 25 10:37:24 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 25 10:37:24 PM:
# (CVXPY) Mar 25 10:37:24 PM: Objective of best integer solution : 0.000000000000e+00
# (CVXPY) Mar 25 10:37:24 PM: Best objective bound               : 0.000000000000e+00
# (CVXPY) Mar 25 10:37:24 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 25 10:37:24 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 25 10:37:24 PM: User objective cut value           : Not employed
# (CVXPY) Mar 25 10:37:24 PM: Number of cuts generated           : 0
# (CVXPY) Mar 25 10:37:24 PM: Number of branches                 : 0
# (CVXPY) Mar 25 10:37:24 PM: Number of relaxations solved       : 1
# (CVXPY) Mar 25 10:37:24 PM: Number of interior point iterations: 0
# (CVXPY) Mar 25 10:37:24 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 25 10:37:24 PM: Time spend presolving the root     : 0.97
# (CVXPY) Mar 25 10:37:24 PM: Time spend optimizing the root     : 0.00
# (CVXPY) Mar 25 10:37:24 PM: Mixed integer optimizer terminated. Time: 1.58
# (CVXPY) Mar 25 10:37:24 PM: Optimizer terminated. Time: 1.65
# (CVXPY) Mar 25 10:37:24 PM:
# (CVXPY) Mar 25 10:37:24 PM:
# (CVXPY) Mar 25 10:37:24 PM: Integer solution solution summary
# (CVXPY) Mar 25 10:37:24 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 25 10:37:24 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 25 10:37:25 PM:   Primal.  obj: 0.0000000000e+00    nrm: 5e+02    Viol.  con: 0e+00    var: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:25 PM: Problem status: optimal
# (CVXPY) Mar 25 10:37:25 PM: Optimal value: 0.000e+00
# (CVXPY) Mar 25 10:37:25 PM: Compilation took 8.224e-01 seconds
# (CVXPY) Mar 25 10:37:25 PM: Solver (including time spent in interface) took 2.032e+00 seconds

# %%
AFFILIATION = rng.permuted(
    np.hstack([np.ones((NUM_AUTHORS,1)), np.zeros((NUM_AUTHORS,NUM_DEPARTMENTS-1))]),
    axis=1
)
AFFILIATION = sp.sparse.bsr_array(AFFILIATION) # sparse

# Variables
assignment = cp.Variable((NUM_AUTHORS, NUM_PRODUCTS), boolean=True)
is_rp_submitted = cp.Variable(NUM_PRODUCTS, boolean=True)

# Expressions
rp_per_author = cp.sum(assignment, axis=1)
num_assigned_rp_authors_per_department = assignment.T @ AFFILIATION

vqr_constraints = [
    # No authorship -> no assignment 
    assignment <= AUTHORSHIP,

    # Min and max number of RPs per author
    rp_per_author <= MAX_NUM_RP_PER_AUTHOR,
    rp_per_author >= MIN_NUM_RP_PER_AUTHOR,
 
    # Max number of assigned RP per author per department   
    num_assigned_rp_authors_per_department <= MAX_NUM_AUTHORS_RP_SAME_DEPARTMENT,
    
    # Definition of is_rp_submitted
    cp.sum(assignment, axis=0) >= is_rp_submitted,
    cp.sum(assignment, axis=0) <= cp.multiply(AUTHORSHIP.sum(axis=0), is_rp_submitted),
    
    # Max number of assigned RPs per department
    cp.sum(num_assigned_rp_authors_per_department, axis=0) <= np.floor(MAX_NUM_AUTHORS_RP_SAME_DEPARTMENT*AFFILIATION.sum(axis=0)),

    # RPs can be presented, at most, in two departments (following VQR4 guidelines)
    cp.sum(num_assigned_rp_authors_per_department, axis=1) <= MAX_NUM_DEPARTMENTS_PRESENTING_SAME_RP
]

# Objectives and indices
carrer_contribution = rp_per_author @ AUTHOR_WEIGHT
expected_evaluation = is_rp_submitted @ AVG_GRADE
# submission_risk = is_rp_submitted.T @ COVARIANCE_MATRIX @ is_rp_submitted
submission_risk = cp.abs(is_rp_submitted) @ VAR_GRADE

# %%
# Get the bounds for expected_evaluation 
max_expected_evaluation_prob = cp.Problem(cp.Maximize(expected_evaluation), vqr_constraints)\
                                 .solve(verbose=True)
max_expected_evaluation = expected_evaluation.value
min_expected_evaluation_prob = cp.Problem(cp.Minimize(expected_evaluation), vqr_constraints)\
                                 .solve(verbose=True)
min_expected_evaluation = expected_evaluation.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:37:25 PM: Your problem has 201000 variables, 8 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:37:25 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:37:25 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:37:25 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:37:25 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:25 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:37:25 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:37:25 PM: Applying reduction FlipObjective
# (CVXPY) Mar 25 10:37:25 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:37:25 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:37:25 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:37:26 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:37:26 PM: Finished problem compilation (took 9.437e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:26 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:37:26 PM: Problem
# (CVXPY) Mar 25 10:37:26 PM:   Name                   :
# (CVXPY) Mar 25 10:37:26 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:37:26 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:37:26 PM:   Constraints            : 208405
# (CVXPY) Mar 25 10:37:26 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:37:26 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:37:26 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:37:26 PM:   Scalar variables       : 201000
# (CVXPY) Mar 25 10:37:26 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:37:26 PM:   Integer variables      : 201000
# (CVXPY) Mar 25 10:37:26 PM:
# (CVXPY) Mar 25 10:37:26 PM: Optimizer started.
# (CVXPY) Mar 25 10:37:27 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:37:27 PM: Threads used: 4
# (CVXPY) Mar 25 10:37:27 PM: Presolve started.
# (CVXPY) Mar 25 10:37:29 PM: Presolve terminated. Time = 2.35, probing time =  0.05
# (CVXPY) Mar 25 10:37:29 PM: Presolved problem: 101024 variables, 8205 constraints, 602144 non-zeros
# (CVXPY) Mar 25 10:37:29 PM: Presolved problem: 0 general integer, 101024 binary, 0 continuous
# (CVXPY) Mar 25 10:37:29 PM: Clique table size: 105024
# (CVXPY) Mar 25 10:37:29 PM: Symmetry factor  : 0.00 (detection time = 0.08)
# (CVXPY) Mar 25 10:37:29 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:37:31 PM: 0        1        1        0        -9.2808855883e+02    -9.2808855883e+02    0.00e+00    4.4
# (CVXPY) Mar 25 10:37:31 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 25 10:37:31 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 25 10:37:31 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 25 10:37:31 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 25 10:37:31 PM:
# (CVXPY) Mar 25 10:37:31 PM: Objective of best integer solution : -9.280885588340e+02
# (CVXPY) Mar 25 10:37:31 PM: Best objective bound               : -9.280885588340e+02
# (CVXPY) Mar 25 10:37:31 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 25 10:37:31 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 25 10:37:31 PM: User objective cut value           : Not employed
# (CVXPY) Mar 25 10:37:31 PM: Number of cuts generated           : 0
# (CVXPY) Mar 25 10:37:31 PM: Number of branches                 : 0
# (CVXPY) Mar 25 10:37:31 PM: Number of relaxations solved       : 1
# (CVXPY) Mar 25 10:37:31 PM: Number of interior point iterations: 13
# (CVXPY) Mar 25 10:37:31 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 25 10:37:31 PM: Time spend presolving the root     : 2.35
# (CVXPY) Mar 25 10:37:31 PM: Time spend optimizing the root     : 1.49
# (CVXPY) Mar 25 10:37:31 PM: Mixed integer optimizer terminated. Time: 4.39
# (CVXPY) Mar 25 10:37:31 PM: Optimizer terminated. Time: 4.44
# (CVXPY) Mar 25 10:37:31 PM:
# (CVXPY) Mar 25 10:37:31 PM:
# (CVXPY) Mar 25 10:37:31 PM: Integer solution solution summary
# (CVXPY) Mar 25 10:37:31 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 25 10:37:31 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 25 10:37:31 PM:   Primal.  obj: -9.2808855883e+02   nrm: 1e+02    Viol.  con: 9e-15    var: 9e-15    itg: 9e-15
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:31 PM: Problem status: optimal
# (CVXPY) Mar 25 10:37:31 PM: Optimal value: 9.281e+02
# (CVXPY) Mar 25 10:37:31 PM: Compilation took 9.437e-01 seconds
# (CVXPY) Mar 25 10:37:31 PM: Solver (including time spent in interface) took 4.754e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:37:31 PM: Your problem has 201000 variables, 8 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:37:31 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:37:31 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:37:31 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:37:31 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:31 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:37:31 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:37:31 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:37:31 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:37:31 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:37:31 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:37:32 PM: Finished problem compilation (took 9.010e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:37:32 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:37:32 PM: Problem
# (CVXPY) Mar 25 10:37:32 PM:   Name                   :
# (CVXPY) Mar 25 10:37:32 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:37:32 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:37:32 PM:   Constraints            : 208405
# (CVXPY) Mar 25 10:37:32 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:37:32 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:37:32 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:37:32 PM:   Scalar variables       : 201000
# (CVXPY) Mar 25 10:37:32 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:37:32 PM:   Integer variables      : 201000
# (CVXPY) Mar 25 10:37:32 PM:
# (CVXPY) Mar 25 10:37:32 PM: Optimizer started.
# (CVXPY) Mar 25 10:37:32 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:37:32 PM: Threads used: 4
# (CVXPY) Mar 25 10:37:32 PM: Presolve started.
# (CVXPY) Mar 25 10:37:34 PM: Presolve terminated. Time = 1.98, probing time =  0.06
# (CVXPY) Mar 25 10:37:34 PM: Presolved problem: 101024 variables, 8205 constraints, 602144 non-zeros
# (CVXPY) Mar 25 10:37:34 PM: Presolved problem: 0 general integer, 101024 binary, 0 continuous
# (CVXPY) Mar 25 10:37:34 PM: Clique table size: 105024
# (CVXPY) Mar 25 10:37:34 PM: Symmetry factor  : 0.00 (detection time = 0.08)
# (CVXPY) Mar 25 10:37:34 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:37:39 PM: 0        1        1        0        NA                   2.4595552182e+00     NA          6.6
# (CVXPY) Mar 25 10:37:39 PM: 0        1        1        0        1.2385610999e+02     2.4595552182e+00     98.01       7.5
# (CVXPY) Mar 25 10:37:39 PM: Cut generation started.
# (CVXPY) Mar 25 10:37:43 PM: 0        1        1        0        1.2385610999e+02     2.4595552182e+00     98.01       10.8
# (CVXPY) Mar 25 10:37:47 PM: 0        2        1        0        1.2385610999e+02     3.1984276744e+00     97.42       15.5
# (CVXPY) Mar 25 10:37:52 PM: 0        3        1        0        1.2385610999e+02     3.9198029624e+00     96.84       19.8
# (CVXPY) Mar 25 10:37:58 PM: 0        4        1        0        1.2385610999e+02     4.6625337362e+00     96.24       26.5
# (CVXPY) Mar 25 10:38:03 PM: 0        5        1        0        1.2385610999e+02     5.4307215566e+00     95.62       31.1
# (CVXPY) Mar 25 10:38:08 PM: 0        6        1        0        1.2385610999e+02     6.3128001185e+00     94.90       35.8
# (CVXPY) Mar 25 10:38:12 PM: 0        7        1        0        1.2385610999e+02     7.1866350149e+00     94.20       40.5
# (CVXPY) Mar 25 10:38:18 PM: 0        8        1        0        1.2385610999e+02     7.9644489903e+00     93.57       46.1
# (CVXPY) Mar 25 10:38:24 PM: 0        9        1        0        1.2385610999e+02     8.8171185667e+00     92.88       51.8
# (CVXPY) Mar 25 10:38:29 PM: 0        10       1        0        1.2385610999e+02     9.7475768176e+00     92.13       56.9
# (CVXPY) Mar 25 10:38:35 PM: 0        11       1        0        1.2385610999e+02     1.0873560460e+02     12.21       62.7
# (CVXPY) Mar 25 10:38:36 PM: Cut generation terminated. Time = 42.38
# (CVXPY) Mar 25 10:38:36 PM: 0        13       1        0        1.2251893431e+02     1.2251893431e+02     0.00e+00    63.9
# (CVXPY) Mar 25 10:38:36 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 25 10:38:36 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 25 10:38:36 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 25 10:38:36 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 25 10:38:36 PM:
# (CVXPY) Mar 25 10:38:36 PM: Objective of best integer solution : 1.225189343069e+02
# (CVXPY) Mar 25 10:38:36 PM: Best objective bound               : 1.225189343069e+02
# (CVXPY) Mar 25 10:38:36 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 25 10:38:36 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 25 10:38:36 PM: User objective cut value           : Not employed
# (CVXPY) Mar 25 10:38:36 PM: Number of cuts generated           : 5512
# (CVXPY) Mar 25 10:38:36 PM:   Number of Gomory cuts            : 1023
# (CVXPY) Mar 25 10:38:36 PM:   Number of CMIR cuts              : 1013
# (CVXPY) Mar 25 10:38:36 PM:   Number of clique cuts            : 2029
# (CVXPY) Mar 25 10:38:36 PM:   Number of knapsack_cover cuts    : 1447
# (CVXPY) Mar 25 10:38:36 PM: Number of branches                 : 0
# (CVXPY) Mar 25 10:38:36 PM: Number of relaxations solved       : 13
# (CVXPY) Mar 25 10:38:36 PM: Number of interior point iterations: 36
# (CVXPY) Mar 25 10:38:36 PM: Number of simplex iterations       : 28381
# (CVXPY) Mar 25 10:38:36 PM: Time spend presolving the root     : 1.98
# (CVXPY) Mar 25 10:38:36 PM: Time spend optimizing the root     : 4.14
# (CVXPY) Mar 25 10:38:36 PM: Mixed integer optimizer terminated. Time: 63.89
# (CVXPY) Mar 25 10:38:36 PM: Optimizer terminated. Time: 63.94
# (CVXPY) Mar 25 10:38:36 PM:
# (CVXPY) Mar 25 10:38:36 PM:
# (CVXPY) Mar 25 10:38:36 PM: Integer solution solution summary
# (CVXPY) Mar 25 10:38:36 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 25 10:38:36 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 25 10:38:36 PM:   Primal.  obj: 1.2251893431e+02    nrm: 1e+02    Viol.  con: 2e-11    var: 9e-12    itg: 9e-12
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:36 PM: Problem status: optimal
# (CVXPY) Mar 25 10:38:36 PM: Optimal value: 1.225e+02
# (CVXPY) Mar 25 10:38:36 PM: Compilation took 9.010e-01 seconds
# (CVXPY) Mar 25 10:38:36 PM: Solver (including time spent in interface) took 6.424e+01 seconds

# %%
# Get the bounds for carrer_contribution
min_carrer_contribution_prob = cp.Problem(cp.Minimize(carrer_contribution), vqr_constraints)\
                                 .solve(verbose=True)
min_carrer_contribution = carrer_contribution.value
max_carrer_contribution_prob = cp.Problem(cp.Maximize(carrer_contribution), vqr_constraints)\
                                 .solve(verbose=True)
max_carrer_contribution = carrer_contribution.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:38:36 PM: Your problem has 201000 variables, 8 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:38:36 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:38:36 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:38:36 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:38:36 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:36 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:38:36 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:38:36 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:38:36 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:38:36 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:38:37 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:38:37 PM: Finished problem compilation (took 9.295e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:37 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:38:37 PM: Problem
# (CVXPY) Mar 25 10:38:37 PM:   Name                   :
# (CVXPY) Mar 25 10:38:37 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:38:37 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:38:37 PM:   Constraints            : 208405
# (CVXPY) Mar 25 10:38:37 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:38:37 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:38:37 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:38:37 PM:   Scalar variables       : 201000
# (CVXPY) Mar 25 10:38:37 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:38:37 PM:   Integer variables      : 201000
# (CVXPY) Mar 25 10:38:37 PM:
# (CVXPY) Mar 25 10:38:37 PM: Optimizer started.
# (CVXPY) Mar 25 10:38:38 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:38:38 PM: Threads used: 4
# (CVXPY) Mar 25 10:38:38 PM: Presolve started.
# (CVXPY) Mar 25 10:38:40 PM: Presolve terminated. Time = 2.28, probing time =  0.06
# (CVXPY) Mar 25 10:38:40 PM: Presolved problem: 101024 variables, 8205 constraints, 602144 non-zeros
# (CVXPY) Mar 25 10:38:40 PM: Presolved problem: 0 general integer, 101024 binary, 0 continuous
# (CVXPY) Mar 25 10:38:40 PM: Clique table size: 105024
# (CVXPY) Mar 25 10:38:40 PM: Symmetry factor  : 0.00 (detection time = 0.08)
# (CVXPY) Mar 25 10:38:40 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:38:41 PM: 0        1        1        0        NA                   4.1300000000e+02     NA          3.9
# (CVXPY) Mar 25 10:38:42 PM: 0        1        1        0        4.1300000000e+02     4.1300000000e+02     0.00e+00    4.7
# (CVXPY) Mar 25 10:38:42 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 25 10:38:42 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 25 10:38:42 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 25 10:38:42 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 25 10:38:42 PM:
# (CVXPY) Mar 25 10:38:42 PM: Objective of best integer solution : 4.130000000000e+02
# (CVXPY) Mar 25 10:38:42 PM: Best objective bound               : 4.130000000000e+02
# (CVXPY) Mar 25 10:38:42 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 25 10:38:42 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 25 10:38:42 PM: User objective cut value           : Not employed
# (CVXPY) Mar 25 10:38:42 PM: Number of cuts generated           : 0
# (CVXPY) Mar 25 10:38:42 PM: Number of branches                 : 0
# (CVXPY) Mar 25 10:38:42 PM: Number of relaxations solved       : 1
# (CVXPY) Mar 25 10:38:42 PM: Number of interior point iterations: 8
# (CVXPY) Mar 25 10:38:42 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 25 10:38:42 PM: Time spend presolving the root     : 2.28
# (CVXPY) Mar 25 10:38:42 PM: Time spend optimizing the root     : 1.06
# (CVXPY) Mar 25 10:38:42 PM: Mixed integer optimizer terminated. Time: 4.73
# (CVXPY) Mar 25 10:38:42 PM: Optimizer terminated. Time: 4.78
# (CVXPY) Mar 25 10:38:42 PM:
# (CVXPY) Mar 25 10:38:42 PM:
# (CVXPY) Mar 25 10:38:42 PM: Integer solution solution summary
# (CVXPY) Mar 25 10:38:42 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 25 10:38:42 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 25 10:38:42 PM:   Primal.  obj: 4.1300000000e+02    nrm: 1e+02    Viol.  con: 2e-16    var: 2e-16    itg: 2e-16
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:42 PM: Problem status: optimal
# (CVXPY) Mar 25 10:38:42 PM: Optimal value: 4.130e+02
# (CVXPY) Mar 25 10:38:42 PM: Compilation took 9.295e-01 seconds
# (CVXPY) Mar 25 10:38:42 PM: Solver (including time spent in interface) took 5.097e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:38:42 PM: Your problem has 201000 variables, 8 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:38:42 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:38:42 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:38:42 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:38:42 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:42 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:38:42 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:38:42 PM: Applying reduction FlipObjective
# (CVXPY) Mar 25 10:38:42 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:38:42 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:38:42 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:38:43 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:38:43 PM: Finished problem compilation (took 9.404e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:43 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:38:43 PM: Problem
# (CVXPY) Mar 25 10:38:43 PM:   Name                   :
# (CVXPY) Mar 25 10:38:43 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:38:43 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:38:43 PM:   Constraints            : 208405
# (CVXPY) Mar 25 10:38:43 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:38:43 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:38:43 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:38:43 PM:   Scalar variables       : 201000
# (CVXPY) Mar 25 10:38:43 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:38:43 PM:   Integer variables      : 201000
# (CVXPY) Mar 25 10:38:43 PM:
# (CVXPY) Mar 25 10:38:43 PM: Optimizer started.
# (CVXPY) Mar 25 10:38:44 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:38:44 PM: Threads used: 4
# (CVXPY) Mar 25 10:38:44 PM: Presolve started.
# (CVXPY) Mar 25 10:38:46 PM: Presolve terminated. Time = 1.95, probing time =  0.05
# (CVXPY) Mar 25 10:38:46 PM: Presolved problem: 101024 variables, 8205 constraints, 602144 non-zeros
# (CVXPY) Mar 25 10:38:46 PM: Presolved problem: 0 general integer, 101024 binary, 0 continuous
# (CVXPY) Mar 25 10:38:46 PM: Clique table size: 105024
# (CVXPY) Mar 25 10:38:46 PM: Symmetry factor  : 0.00 (detection time = 0.07)
# (CVXPY) Mar 25 10:38:46 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:38:47 PM: 0        1        1        0        NA                   -4.1300000000e+02    NA          3.5
# (CVXPY) Mar 25 10:38:48 PM: 0        1        1        0        -4.1300000000e+02    -4.1300000000e+02    0.00e+00    4.4
# (CVXPY) Mar 25 10:38:48 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 25 10:38:48 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 25 10:38:48 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 25 10:38:48 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 25 10:38:48 PM:
# (CVXPY) Mar 25 10:38:48 PM: Objective of best integer solution : -4.130000000000e+02
# (CVXPY) Mar 25 10:38:48 PM: Best objective bound               : -4.130000000000e+02
# (CVXPY) Mar 25 10:38:48 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 25 10:38:48 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 25 10:38:48 PM: User objective cut value           : Not employed
# (CVXPY) Mar 25 10:38:48 PM: Number of cuts generated           : 0
# (CVXPY) Mar 25 10:38:48 PM: Number of branches                 : 0
# (CVXPY) Mar 25 10:38:48 PM: Number of relaxations solved       : 1
# (CVXPY) Mar 25 10:38:48 PM: Number of interior point iterations: 7
# (CVXPY) Mar 25 10:38:48 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 25 10:38:48 PM: Time spend presolving the root     : 1.95
# (CVXPY) Mar 25 10:38:48 PM: Time spend optimizing the root     : 1.01
# (CVXPY) Mar 25 10:38:48 PM: Mixed integer optimizer terminated. Time: 4.37
# (CVXPY) Mar 25 10:38:48 PM: Optimizer terminated. Time: 4.42
# (CVXPY) Mar 25 10:38:48 PM:
# (CVXPY) Mar 25 10:38:48 PM:
# (CVXPY) Mar 25 10:38:48 PM: Integer solution solution summary
# (CVXPY) Mar 25 10:38:48 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 25 10:38:48 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 25 10:38:48 PM:   Primal.  obj: -4.1300000000e+02   nrm: 1e+02    Viol.  con: 3e-15    var: 9e-17    itg: 3e-15
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:48 PM: Problem status: optimal
# (CVXPY) Mar 25 10:38:48 PM: Optimal value: 4.130e+02
# (CVXPY) Mar 25 10:38:48 PM: Compilation took 9.404e-01 seconds
# (CVXPY) Mar 25 10:38:48 PM: Solver (including time spent in interface) took 4.719e+00 seconds

# %%
# Markowitz formulation
MARKOWITZ_TRADEOFF = 0
MAX_RISK = 15
MIN_EVALUATION = 0.4
normalized_evaluation_carrer_tradeoff = \
    (carrer_contribution - min_carrer_contribution)/np.maximum(1, max_carrer_contribution - min_carrer_contribution) + \
    (expected_evaluation - min_expected_evaluation)/np.maximum(1, max_expected_evaluation - min_expected_evaluation)

markowitz_tradeoff = \
    MARKOWITZ_TRADEOFF*normalized_evaluation_carrer_tradeoff - (1 - MARKOWITZ_TRADEOFF)*submission_risk

markowitz_constraints = []
if MARKOWITZ_TRADEOFF == 1:
    markowitz_constraints.append(
        # submission_risk <= COVARIANCE_MATRIX.sum() * (1 - np.floor(MARKOWITZ_TRADEOFF)) * MAX_RISK
        submission_risk <= MAX_RISK
    )
elif MARKOWITZ_TRADEOFF == 0:
    markowitz_constraints.append(
        # expected_evaluation >= np.ceil(MARKOWITZ_TRADEOFF) * MIN_EVALUATION
        normalized_evaluation_carrer_tradeoff >= MIN_EVALUATION
    )

markowitz = cp.Problem(cp.Maximize(markowitz_tradeoff), vqr_constraints + markowitz_constraints)
markowitz.solve(verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 25 10:38:48 PM: Your problem has 201000 variables, 9 constraints, and 0 parameters.
# (CVXPY) Mar 25 10:38:48 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 25 10:38:48 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 25 10:38:48 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 25 10:38:48 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:48 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 25 10:38:48 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 25 10:38:48 PM: Applying reduction FlipObjective
# (CVXPY) Mar 25 10:38:48 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 25 10:38:48 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 25 10:38:48 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 25 10:38:48 PM: Applying reduction MOSEK
# (CVXPY) Mar 25 10:38:49 PM: Finished problem compilation (took 1.064e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 25 10:38:49 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 25 10:38:49 PM: Problem
# (CVXPY) Mar 25 10:38:49 PM:   Name                   :
# (CVXPY) Mar 25 10:38:49 PM:   Objective sense        : minimize
# (CVXPY) Mar 25 10:38:49 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Mar 25 10:38:49 PM:   Constraints            : 210406
# (CVXPY) Mar 25 10:38:49 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 25 10:38:49 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 25 10:38:49 PM:   Cones                  : 0
# (CVXPY) Mar 25 10:38:49 PM:   Scalar variables       : 202000
# (CVXPY) Mar 25 10:38:49 PM:   Matrix variables       : 0
# (CVXPY) Mar 25 10:38:49 PM:   Integer variables      : 201000
# (CVXPY) Mar 25 10:38:49 PM:
# (CVXPY) Mar 25 10:38:49 PM: Optimizer started.
# (CVXPY) Mar 25 10:38:50 PM: Mixed integer optimizer started.
# (CVXPY) Mar 25 10:38:50 PM: Threads used: 4
# (CVXPY) Mar 25 10:38:50 PM: Presolve started.
# (CVXPY) Mar 25 10:38:52 PM: Presolve terminated. Time = 2.64, probing time =  0.06
# (CVXPY) Mar 25 10:38:52 PM: Presolved problem: 101024 variables, 8206 constraints, 703168 non-zeros
# (CVXPY) Mar 25 10:38:52 PM: Presolved problem: 0 general integer, 101024 binary, 0 continuous
# (CVXPY) Mar 25 10:38:52 PM: Clique table size: 105024
# (CVXPY) Mar 25 10:38:52 PM: Symmetry factor  : 0.00 (detection time = 0.07)
# (CVXPY) Mar 25 10:38:52 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 25 10:39:00 PM: 0        1        1        0        NA                   2.1980339483e+01     NA          11.1
# (CVXPY) Mar 25 10:39:26 PM: 0        1        1        0        2.2066368867e+01     2.1980339483e+01     0.39        36.3
# (CVXPY) Mar 25 10:39:26 PM: Cut generation started.
# (CVXPY) Mar 25 10:39:33 PM: 0        1        1        0        2.2066368867e+01     2.1980339483e+01     0.39        44.2
# (CVXPY) Mar 25 10:39:34 PM: Cut generation terminated. Time = 7.78
# (CVXPY) Mar 25 10:39:35 PM: 0        12       1        0        2.2066368867e+01     2.1982128144e+01     0.38        46.2
# (CVXPY) Mar 25 10:39:35 PM: 7        23       1        0        2.2066368867e+01     2.1982128144e+01     0.38        46.2
# (CVXPY) Mar 25 10:39:35 PM: 19       35       1        0        2.2066368867e+01     2.1982128144e+01     0.38        46.2
# (CVXPY) Mar 25 10:39:36 PM: 32       46       4        1        2.2066368867e+01     2.1982128144e+01     0.38        46.7
# (CVXPY) Mar 25 10:39:37 PM: 43       57       15       3        2.2066368867e+01     2.1982128144e+01     0.38        47.9
# (CVXPY) Mar 25 10:39:38 PM: 55       69       27       5        2.2066368867e+01     2.1982128144e+01     0.38        48.9
# (CVXPY) Mar 25 10:39:40 PM: 79       93       51       11       2.2066368867e+01     2.1982128144e+01     0.38        50.9
